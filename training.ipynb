# %%
pip install yfinance alpha_vantage quandl pandas numpy
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.43-py2.py3-none-any.whl.metadata (11 kB)
# Collecting alpha_vantage
#   Downloading alpha_vantage-3.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting quandl
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Collecting requests>=2.31 (from yfinance)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\uno\appdata\roaming\python\python312\site-packages (from yfinance) (4.3.3)
# Collecting pytz>=2022.5 (from yfinance)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.4-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ------- -------------------------------- 0.5/3.0 MB 2.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.3/3.0 MB 3.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.1/3.0 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 1.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting aiohttp (from alpha_vantage)
#   Downloading aiohttp-3.10.5-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting inflection>=0.3.1 (from quandl)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil in c:\users\uno\appdata\roaming\python\python312\site-packages (from quandl) (2.9.0.post0)
# Requirement already satisfied: six in c:\users\uno\appdata\roaming\python\python312\site-packages (from quandl) (1.16.0)
# Collecting more-itertools (from quandl)
#   Downloading more_itertools-10.5.0-py3-none-any.whl.metadata (36 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting webencodings (from html5lib>=1.1->yfinance)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Downloading idna-3.9-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.31->yfinance)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->alpha_vantage)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->alpha_vantage)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->alpha_vantage)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->alpha_vantage)
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->alpha_vantage)
#   Downloading multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->alpha_vantage)
#   Downloading yarl-1.11.1-cp312-cp312-win_amd64.whl.metadata (49 kB)
# Downloading yfinance-0.2.43-py2.py3-none-any.whl (84 kB)
# Downloading alpha_vantage-3.0.0-py3-none-any.whl (35 kB)
# Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 3.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.5 MB 3.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/11.5 MB 3.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 3.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.5 MB 3.7 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 3.8 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.5 MB 3.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 3.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 2.7 MB/s eta 0:00:00
# Downloading numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 2.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.6 MB 3.5 MB/s eta 0:00:04
#    ------ --------------------------------- 2.1/12.6 MB 3.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.6 MB 3.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.6 MB 3.6 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.6 MB 3.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.6 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.6 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.6 MB 3.7 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.6 MB 3.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.6 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 2.7 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading frozendict-2.4.4-py312-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 4.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 4.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 2.4 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading aiohttp-3.10.5-cp312-cp312-win_amd64.whl (377 kB)
# Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
# Downloading idna-3.9-py3-none-any.whl (71 kB)
# Downloading multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading yarl-1.11.1-cp312-cp312-win_amd64.whl (110 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.6-py3-none-any.whl size=138939 sha256=8c8a7a12a756bb4e88180a8bb999cde71ff7f4ca911a1a6eb4033edcfbb6d15a
#   Stored in directory: c:\users\uno\appdata\local\pip\cache\wheels\a6\5e\0f\8319805c4115320e0d3e8fb5799b114a2e4c4a3d6c7e523b06
# Successfully built peewee
# Installing collected packages: webencodings, pytz, peewee, multitasking, urllib3, tzdata, soupsieve, numpy, multidict, more-itertools, lxml, inflection, idna, html5lib, frozenlist, frozendict, charset-normalizer, certifi, attrs, aiohappyeyeballs, yarl, requests, pandas, beautifulsoup4, aiosignal, yfinance, quandl, aiohttp, alpha_vantage
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 alpha_vantage-3.0.0 attrs-24.2.0 beautifulsoup4-4.12.3 certifi-2024.8.30 charset-normalizer-3.3.2 frozendict-2.4.4 frozenlist-1.4.1 html5lib-1.1 idna-3.9 inflection-0.5.1 lxml-5.3.0 more-itertools-10.5.0 multidict-6.1.0 multitasking-0.0.11 numpy-2.1.1 pandas-2.2.2 peewee-3.17.6 pytz-2024.2 quandl-3.7.0 requests-2.32.3 soupsieve-2.6 tzdata-2024.1 urllib3-2.2.3 webencodings-0.5.1 yarl-1.11.1 yfinance-0.2.43
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\UNO\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\UNO\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sample.exe is installed in 'c:\Users\UNO\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from alpha_vantage.timeseries import TimeSeries

# Initialize API
api_key = 'your_api_key'
ts = TimeSeries(key=api_key, output_format='pandas')

# Get daily stock data for a single asset
data, meta_data = ts.get_daily(symbol='AAPL', outputsize='full')

# View the data
print(data.head())
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2024-09-13  223.580   224.04  221.91    222.50  36766619.0
# 2024-09-12  222.500   223.55  219.82    222.77  37498225.0
# 2024-09-11  221.455   223.09  217.89    222.66  44587072.0
# 2024-09-10  218.920   221.48  216.73    220.11  51591033.0
# 2024-09-09  220.820   221.27  216.71    220.91  67179965.0

# %%
import yfinance as yf
import pandas as pd

assets = ['AAPL', 'GOOGL', 'MSFT']
data = yf.download(assets, start='2020-01-01', end='2023-01-01')

# Save to CSV
data.to_csv('stock_data.csv')
# Out:
# [*********************100%***********************]  3 of 3 completed
